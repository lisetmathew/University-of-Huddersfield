# %% [markdown]
# # Student's Performance Dataset Analysis

# %% [markdown]
# ### Importing Libraries

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
import matplotlib.pyplot as plt
from scipy.stats import norm
import seaborn as sns
import numpy as np 
import pandas as pd

# %% [markdown]
# ### Reading the dataset student-mat

# %%
student_mat=pd.read_csv('studentmat.csv')
student_mat
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        6   5   6   6
# 1    ...      5        3      3     1     1      3        4   5   5   6
# 2    ...      4        3      2     2     3      3       10   7   8  10
# 3    ...      3        2      2     1     1      5        2  15  14  15
# 4    ...      4        3      2     1     2      5        4   6  10  10
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 390  ...      5        5      4     4     5      4       11   9   9   9
# 391  ...      2        4      5     3     4      2        3  14  16  16
# 392  ...      5        5      3     3     3      3        3  10   8   7
# 393  ...      4        4      1     3     4      5        0  11  12  10
# 394  ...      3        2      3     3     3      5        5   8   9   9
#
# [395 rows x 33 columns]

# %%
student_mat.shape
# Out:
# (395, 33)

# %%
student_mat.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ### Reading the dataset student-por

# %%
student_por=pd.read_csv('studentpor.csv')
student_por
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0    ...      4        3      4     1     1      3        4   0  11  11
# 1    ...      5        3      3     1     1      3        2   9  11  11
# 2    ...      4        3      2     2     3      3        6  12  13  12
# 3    ...      3        2      2     1     1      5        0  14  14  14
# 4    ...      4        3      2     1     2      5        0  11  13  13
# ..   ...    ...      ...    ...   ...   ...    ...      ...  ..  ..  ..
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [649 rows x 33 columns]

# %%
student_por.shape
# Out:
# (649, 33)

# %%
student_por.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'fatherd', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %% [markdown]
# ### Appending both student-mat and student-por dataset

# %%
student_data=student_mat.append(student_por)
student_data
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 fatherd
# 0    ...        3     4     1     1       3        6   5   6   6     NaN
# 1    ...        3     3     1     1       3        4   5   5   6     NaN
# 2    ...        3     2     2     3       3       10   7   8  10     NaN
# 3    ...        2     2     1     1       5        2  15  14  15     NaN
# 4    ...        3     2     1     2       5        4   6  10  10     NaN
# ..   ...      ...   ...   ...   ...     ...      ...  ..  ..  ..     ...
# 644  ...        4     2     1     2       5        4  10  11  10      no
# 645  ...        3     4     1     1       1        4  15  15  16      no
# 646  ...        1     1     1     1       5        6  11  12   9      no
# 647  ...        4     5     3     4       2        6  10  10  10      no
# 648  ...        4     1     3     4       5        4  10  11  11      no
#
# [1044 rows x 34 columns]

# %%
student_data.shape
# Out:
# (1044, 34)

# %%
student_data.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3', 'fatherd'],
#       dtype='object')

# %% [markdown]
# ### Descriptive statistics

# %%
student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1044 entries, 0 to 648
# Data columns (total 34 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      1044 non-null   object
#  1   sex         1044 non-null   object
#  2   age         1044 non-null   int64
#  3   address     1044 non-null   object
#  4   famsize     1044 non-null   object
#  5   Pstatus     1044 non-null   object
#  6   Medu        1044 non-null   int64
#  7   Fedu        1044 non-null   int64
#  8   Mjob        1044 non-null   object
#  9   Fjob        1044 non-null   object
#  10  reason      1044 non-null   object
#  11  guardian    1044 non-null   object
#  12  traveltime  1044 non-null   int64
#  13  studytime   1044 non-null   int64
#  14  failures    1044 non-null   int64
#  15  schoolsup   1044 non-null   object
#  16  famsup      1044 non-null   object
#  17  paid        395 non-null    object
#  18  activities  1044 non-null   object
#  19  nursery     1044 non-null   object
#  20  higher      1044 non-null   object
#  21  internet    1044 non-null   object
#  22  romantic    1044 non-null   object
#  23  famrel      1044 non-null   int64
#  24  freetime    1044 non-null   int64
#  25  goout       1044 non-null   int64
#  26  Dalc        1044 non-null   int64
#  27  Walc        1044 non-null   int64
#  28  health      1044 non-null   int64
#  29  absences    1044 non-null   int64
#  30  G1          1044 non-null   int64
#  31  G2          1044 non-null   int64
#  32  G3          1044 non-null   int64
#  33  fatherd     649 non-null    object
# dtypes: int64(16), object(18)
# memory usage: 285.5+ KB

# %%
student_data.describe()
# Out:
#                age         Medu         Fedu   traveltime    studytime  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean     16.726054     2.603448     2.387931     1.522989     1.970307
# std       1.239975     1.124907     1.099938     0.731727     0.834353
# min      15.000000     0.000000     0.000000     1.000000     1.000000
# 25%      16.000000     2.000000     1.000000     1.000000     1.000000
# 50%      17.000000     3.000000     2.000000     1.000000     2.000000
# 75%      18.000000     4.000000     3.000000     2.000000     2.000000
# max      22.000000     4.000000     4.000000     4.000000     4.000000
#
#           failures       famrel     freetime        goout         Dalc  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      0.264368     3.935824     3.201149     3.156130     1.494253
# std       0.656142     0.933401     1.031507     1.152575     0.911714
# min       0.000000     1.000000     1.000000     1.000000     1.000000
# 25%       0.000000     4.000000     3.000000     2.000000     1.000000
# 50%       0.000000     4.000000     3.000000     3.000000     1.000000
# 75%       0.000000     5.000000     4.000000     4.000000     2.000000
# max       3.000000     5.000000     5.000000     5.000000     5.000000
#
#               Walc       health     absences           G1           G2  \
# count  1044.000000  1044.000000  1044.000000  1044.000000  1044.000000
# mean      2.284483     3.543103     4.434866    11.213602    11.246169
# std       1.285105     1.424703     6.210017     2.983394     3.285071
# min       1.000000     1.000000     0.000000     0.000000     0.000000
# 25%       1.000000     3.000000     0.000000     9.000000     9.000000
# 50%       2.000000     4.000000     2.000000    11.000000    11.000000
# 75%       3.000000     5.000000     6.000000    13.000000    13.000000
# max       5.000000     5.000000    75.000000    19.000000    19.000000
#
#                 G3
# count  1044.000000
# mean     11.341954
# std       3.864796
# min       0.000000
# 25%      10.000000
# 50%      11.000000
# 75%      14.000000
# max      20.000000

# %%
student_data['G1'].describe()
# Out:
# count    1044.000000
# mean       11.213602
# std         2.983394
# min         0.000000
# 25%         9.000000
# 50%        11.000000
# 75%        13.000000
# max        19.000000
# Name: G1, dtype: float64

# %%
student_data['G2'].describe()
# Out:
# count    1044.000000
# mean       11.246169
# std         3.285071
# min         0.000000
# 25%         9.000000
# 50%        11.000000
# 75%        13.000000
# max        19.000000
# Name: G2, dtype: float64

# %%
student_data['G3'].describe()
# Out:
# count    1044.000000
# mean       11.341954
# std         3.864796
# min         0.000000
# 25%        10.000000
# 50%        11.000000
# 75%        14.000000
# max        20.000000
# Name: G3, dtype: float64

# %%
student_data['sex'].value_counts()
# Out:
# F    591
# M    453
# Name: sex, dtype: int64

# %%
student_data['age'].value_counts()
# Out:
# 16    281
# 17    277
# 18    222
# 15    194
# 19     56
# 20      9
# 21      3
# 22      2
# Name: age, dtype: int64

# %% [markdown]
# ### Checking the missing values and cleaning it

# %%
student_data.isna().sum()
# Out:
# school          0
# sex             0
# age             0
# address         0
# famsize         0
# Pstatus         0
# Medu            0
# Fedu            0
# Mjob            0
# Fjob            0
# reason          0
# guardian        0
# traveltime      0
# studytime       0
# failures        0
# schoolsup       0
# famsup          0
# paid          649
# activities      0
# nursery         0
# higher          0
# internet        0
# romantic        0
# famrel          0
# freetime        0
# goout           0
# Dalc            0
# Walc            0
# health          0
# absences        0
# G1              0
# G2              0
# G3              0
# fatherd       395
# dtype: int64

# %%
student_data.fillna(0,axis=1,inplace=True)

# %%
student_data.isna().sum().sum()
# Out:
# 0

# %%
student_data.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# fatherd       0
# dtype: int64

# %% [markdown]
# ### Dropping unwanted columns

# %%
student_data1=student_data.drop(['reason','guardian','traveltime','studytime','failures',
                                 'schoolsup','famsup','paid','activities','nursery','higher',
                                 'romantic','famrel','freetime','goout','Dalc','Walc','fatherd'],axis=1)
student_data1
# Out:
#     school sex age address famsize Pstatus Medu Fedu      Mjob      Fjob  \
# 0       GP   F  18       U     GT3       A    4    4   at_home   teacher
# 1       GP   F  17       U     GT3       T    1    1   at_home     other
# 2       GP   F  15       U     LE3       T    1    1   at_home     other
# 3       GP   F  15       U     GT3       T    4    2    health  services
# 4       GP   F  16       U     GT3       T    3    3     other     other
# ..     ...  ..  ..     ...     ...     ...  ...  ...       ...       ...
# 644     MS   F  19       R     GT3       T    2    3  services     other
# 645     MS   F  18       U     LE3       T    3    1   teacher  services
# 646     MS   F  18       U     GT3       T    1    1     other     other
# 647     MS   M  17       U     LE3       T    3    1  services  services
# 648     MS   M  18       R     LE3       T    3    2  services     other
#
#     internet health absences  G1  G2  G3
# 0         no      3        6   5   6   6
# 1        yes      3        4   5   5   6
# 2        yes      3       10   7   8  10
# 3        yes      5        2  15  14  15
# 4         no      5        4   6  10  10
# ..       ...    ...      ...  ..  ..  ..
# 644      yes      5        4  10  11  10
# 645      yes      1        4  15  15  16
# 646       no      5        6  11  12   9
# 647      yes      2        6  10  10  10
# 648      yes      5        4  10  11  11
#
# [1044 rows x 16 columns]

# %% [markdown]
# ### Checking the unique values for columns

# %%
student_data1['school'].unique()
# Out:
# array(['GP', 'MS'], dtype=object)

# %%
student_data1['sex'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
student_data1['address'].unique()
# Out:
# array(['U', 'R'], dtype=object)

# %%
student_data1['famsize'].unique()
# Out:
# array(['GT3', 'LE3'], dtype=object)

# %%
student_data1['Pstatus'].unique()
# Out:
# array(['A', 'T'], dtype=object)

# %%
student_data1['Mjob'].unique()
# Out:
# array(['at_home', 'health', 'other', 'services', 'teacher'], dtype=object)

# %%
student_data1['Fjob'].unique()
# Out:
# array(['teacher', 'other', 'services', 'health', 'at_home'], dtype=object)

# %%
student_data1['internet'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %% [markdown]
# ### Changing the variables to integer

# %%
student_data1.sex=student_data1.sex.replace({'M':1,'F':0})

# %%
student_data1.school=student_data1.school.replace({'MS':1,'GP':0})

# %%
student_data1.address=student_data1.address.replace({'U':1,'R':0})

# %%
student_data1.famsize=student_data1.famsize.replace({'GT3':1,'LE3':0})

# %%
student_data1.Pstatus=student_data1.Pstatus.replace({'A':1,'T':0})

# %%
student_data1.Mjob=student_data1.Mjob.replace({'health':2,'at_home':1,'services':3,'teacher':4,'other':0})

# %%
student_data1.Fjob=student_data1.Fjob.replace({'health':2,'at_home':1,'services':3,'teacher':4,'other':0})

# %%
student_data1.internet=student_data1.internet.replace({'yes':1,'no':0})

# %%
student_data1
# Out:
#      school  sex age  address  famsize  Pstatus Medu Fedu  Mjob  Fjob  \
# 0         0    0  18        1        1        1    4    4     1     4
# 1         0    0  17        1        1        0    1    1     1     0
# 2         0    0  15        1        0        0    1    1     1     0
# 3         0    0  15        1        1        0    4    2     2     3
# 4         0    0  16        1        1        0    3    3     0     0
# ..      ...  ...  ..      ...      ...      ...  ...  ...   ...   ...
# 644       1    0  19        0        1        0    2    3     3     0
# 645       1    0  18        1        0        0    3    1     4     3
# 646       1    0  18        1        1        0    1    1     0     0
# 647       1    1  17        1        0        0    3    1     3     3
# 648       1    1  18        0        0        0    3    2     3     0
#
#      internet health absences  G1  G2  G3
# 0           0      3        6   5   6   6
# 1           1      3        4   5   5   6
# 2           1      3       10   7   8  10
# 3           1      5        2  15  14  15
# 4           0      5        4   6  10  10
# ..        ...    ...      ...  ..  ..  ..
# 644         1      5        4  10  11  10
# 645         1      1        4  15  15  16
# 646         0      5        6  11  12   9
# 647         1      2        6  10  10  10
# 648         1      5        4  10  11  11
#
# [1044 rows x 16 columns]

# %% [markdown]
# ### finding the frequency and distribution of G3 with other columns

# %%
ss=pd.crosstab(student_data1['sex'],student_data1['school'])
ss
# Out:
# school    0    1
# sex
# 0       420  171
# 1       352  101

# %%
ss.plot(kind='bar',stacked=True)
plt.xlabel('sex')
plt.ylabel('school')
plt.show()

# %%
sa=pd.crosstab(student_data1['address'],student_data1['school'])
sa
# Out:
# school     0    1
# address
# 0        141  144
# 1        631  128

# %%
sa.plot(kind='bar',stacked=True)
plt.xlabel('address')
plt.ylabel('school')
plt.show()

# %%
student_data1.groupby('famsize')[['address','school']].sum().plot.bar(color=['blue','red'],figsize=(8,5))
plt.ylabel('ADDRESS AND SCHOOL')
plt.show()

# %%
student_data1.groupby('internet')[['sex','address']].sum().plot.bar(color=['red','green'],figsize=(8,5))
plt.ylabel('INTERNET USAGE')
plt.show()

# %%
plt.title('internet usage',fontsize=20)
student_data1['internet'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.title('mothers education',fontsize=20)
student_data1['Medu'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.title('fathers education',fontsize=20)
student_data1['Fedu'].value_counts().plot.pie(autopct='%1.1f%%',shadow=True)
plt.show()

# %% [markdown]
# ### Factor analysis

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaled_data = scaler.fit_transform(student_data1)
scaled_data = pd.DataFrame(scaled_data, columns=student_data1.columns)
scaled_data.head(3)
# Out:
#      school       sex       age   address   famsize   Pstatus      Medu  \
# 0 -0.593575 -0.875498  1.027889  0.612776  0.643921  2.761901  1.242077
# 1 -0.593575 -0.875498  0.221035  0.612776  0.643921 -0.362069 -1.426089
# 2 -0.593575 -0.875498 -1.392674  0.612776 -1.552986 -0.362069 -1.426089
#
#        Fedu      Mjob      Fjob  internet    health  absences        G1  \
# 0  1.466302 -0.354335  1.858957 -1.952194 -0.381387  0.252155 -2.083727
# 1 -1.262431 -0.354335 -0.821639  0.512244 -0.381387 -0.070060 -2.083727
# 2 -1.262431 -0.354335 -0.821639  0.512244 -0.381387  0.896584 -1.413029
#
#          G2        G3
# 0 -1.597738 -1.382871
# 1 -1.902291 -1.382871
# 2 -0.988631 -0.347391

# %%
student_data1.cov()
# Out:
#             school       sex   address   famsize   Pstatus      Mjob  \
# school    0.192842 -0.016321 -0.066872 -0.006976 -0.003380 -0.096410
# sex      -0.016321  0.245867  0.002554 -0.021308 -0.008152  0.087168
# address  -0.066872  0.002554  0.198656 -0.011059  0.010577  0.081895
# famsize  -0.006976 -0.021308 -0.011059  0.207392 -0.030234 -0.048418
# Pstatus  -0.003380 -0.008152  0.010577 -0.030234  0.102566 -0.002743
# Mjob     -0.096410  0.087168  0.081895 -0.048418 -0.002743  2.220704
# Fjob      0.010080  0.030295  0.034924  0.028928 -0.026225  0.666773
# internet -0.039754  0.012616  0.035246 -0.001537 -0.008485  0.123229
#
#               Fjob  internet
# school    0.010080 -0.039754
# sex       0.030295  0.012616
# address   0.034924  0.035246
# famsize   0.028928 -0.001537
# Pstatus  -0.026225 -0.008485
# Mjob      0.666773  0.123229
# Fjob      2.228812  0.026897
# internet  0.026897  0.164809

# %%
sns.heatmap(student_data1.cov(),vmin=-1,vmax=1,cmap='RdBu',linewidth=1,square=True)
plt.show()

# %% [markdown]
# ### Random Forest Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
x=student_data1.drop(['G3'],axis=1)
y=student_data1['G3']

# %%
x
# Out:
#      school  sex age  address  famsize  Pstatus Medu Fedu  Mjob  Fjob  \
# 0         0    0  18        1        1        1    4    4     1     4
# 1         0    0  17        1        1        0    1    1     1     0
# 2         0    0  15        1        0        0    1    1     1     0
# 3         0    0  15        1        1        0    4    2     2     3
# 4         0    0  16        1        1        0    3    3     0     0
# ..      ...  ...  ..      ...      ...      ...  ...  ...   ...   ...
# 644       1    0  19        0        1        0    2    3     3     0
# 645       1    0  18        1        0        0    3    1     4     3
# 646       1    0  18        1        1        0    1    1     0     0
# 647       1    1  17        1        0        0    3    1     3     3
# 648       1    1  18        0        0        0    3    2     3     0
#
#      internet health absences  G1  G2
# 0           0      3        6   5   6
# 1           1      3        4   5   5
# 2           1      3       10   7   8
# 3           1      5        2  15  14
# 4           0      5        4   6  10
# ..        ...    ...      ...  ..  ..
# 644         1      5        4  10  11
# 645         1      1        4  15  15
# 646         0      5        6  11  12
# 647         1      2        6  10  10
# 648         1      5        4  10  11
#
# [1044 rows x 15 columns]

# %%
y
# Out:
# 0       6
# 1       6
# 2      10
# 3      15
# 4      10
#        ..
# 644    10
# 645    16
# 646     9
# 647    10
# 648    11
# Name: G3, Length: 1044, dtype: object

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (835, 15)
# (209, 15)
# (835,)
# (209,)

# %%
model = RandomForestRegressor(random_state=1)

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=1)

# %%
y_predict = model.predict(x_test)
y_predict
# Out:
# array([ 7.25      ,  8.47      , 15.36      , 13.03      ,  5.11      ,
#        11.25      , 11.06      , 12.9       , 14.83      , 11.09      ,
#        17.83      ,  7.03      ,  9.58      , 14.74      ,  9.53      ,
#         8.82      , 14.55      , 13.211     ,  9.23      ,  6.33      ,
#         4.99      , 17.61      ,  9.02      , 17.23      ,  9.74      ,
#        10.05      , 10.11      , 13.525     , 11.02      , 10.56      ,
#        11.33      , 16.21      , 12.65      ,  8.54      , 12.34      ,
#        10.16      , 12.71      ,  9.41      , 12.69      , 12.45      ,
#        12.935     , 10.25      , 15.93      ,  0.28      , 12.08      ,
#         0.08      , 10.21      , 11.43      , 13.19      , 10.67      ,
#         9.67      , 16.        , 11.1       ,  7.93      , 14.51      ,
#         9.78      , 13.51      ,  9.91      , 12.17      ,  8.22      ,
#         9.44      , 10.21      ,  9.66      , 11.16      , 10.92      ,
#        11.        , 12.54      , 11.2       , 14.9       , 15.09      ,
#        16.03      , 13.3       , 10.48      , 15.55      ,  9.81      ,
#        18.12      , 12.38      ,  6.81      , 10.39      , 17.46      ,
#         9.65      ,  8.17      ,  1.63      , 13.225     , 10.23      ,
#        11.08      , 14.38      , 11.31      , 15.76      ,  3.09      ,
#        10.13      , 11.2       , 13.48      ,  0.        ,  7.58      ,
#         8.52      ,  7.74      , 16.12      , 11.9       ,  9.29      ,
#         0.23      , 13.36      , 13.26      ,  9.12      ,  3.98      ,
#        11.        , 13.08      , 10.75      ,  9.28      ,  9.07      ,
#        11.26      , 11.1       ,  0.        ,  1.2       , 11.27      ,
#        13.73166667,  9.8       , 15.9       ,  0.65      , 15.88      ,
#        10.52      , 10.37      , 11.17      , 11.13      , 12.99      ,
#        13.25      , 10.79      , 10.88      , 16.16      , 10.78      ,
#         9.82      , 16.05      , 13.3       ,  9.03      , 11.07      ,
#        12.42      , 14.7       , 13.04      , 11.07      , 14.4       ,
#        10.9       , 11.54      , 10.79      , 15.07      , 14.69      ,
#        13.51      , 15.01      , 12.68      , 16.36      , 13.        ,
#        17.62      , 10.65      ,  8.21      ,  0.16      , 15.        ,
#         8.46      , 16.02      ,  6.59      ,  8.73      , 11.65      ,
#         9.51      , 10.63      , 12.68      ,  9.24      , 10.58      ,
#        10.09      , 11.89      , 14.5       , 15.92      , 10.23      ,
#         9.78      , 15.33      , 11.52      , 15.92      , 15.86      ,
#        10.93      ,  8.56      ,  7.29      , 10.09      ,  8.7       ,
#        14.2       , 17.69      , 11.        , 15.56      , 17.13      ,
#        11.16      , 12.755     , 14.77      , 10.07      ,  4.57      ,
#        11.78      ,  6.58      , 13.        , 10.86      , 13.01      ,
#         9.57      , 12.88      , 13.07      , 12.89      , 10.5       ,
#        15.5       , 11.35      , 11.25      ,  7.48      , 13.5       ,
#        10.31      ,  6.31      , 12.67      ,  8.36      ])

# %%
from sklearn.metrics import mean_squared_error

# %%
mse = mean_squared_error(y_test,y_predict)
mse
# Out:
# 2.709438391281233

# %% [markdown]
# ### Dividing the dataset into 3 categories: poor achieving students, average achieving, well achieving

# %%
def G3(grade):
    if grade<7:
        return 'poor_achieving'
    elif grade<14:
        return 'average_achieving'
    else:
        return 'well_achieving'

# %%
student_data1['G3']=student_data1['G3'].apply(G3)
student_data1
# Out:
#      school  sex age  address  famsize  Pstatus Medu Fedu  Mjob  Fjob  \
# 0         0    0  18        1        1        1    4    4     1     4
# 1         0    0  17        1        1        0    1    1     1     0
# 2         0    0  15        1        0        0    1    1     1     0
# 3         0    0  15        1        1        0    4    2     2     3
# 4         0    0  16        1        1        0    3    3     0     0
# ..      ...  ...  ..      ...      ...      ...  ...  ...   ...   ...
# 644       1    0  19        0        1        0    2    3     3     0
# 645       1    0  18        1        0        0    3    1     4     3
# 646       1    0  18        1        1        0    1    1     0     0
# 647       1    1  17        1        0        0    3    1     3     3
# 648       1    1  18        0        0        0    3    2     3     0
#
#      internet health absences  G1  G2                 G3
# 0           0      3        6   5   6     poor_achieving
# 1           1      3        4   5   5     poor_achieving
# 2           1      3       10   7   8  average_achieving
# 3           1      5        2  15  14     well_achieving
# 4           0      5        4   6  10  average_achieving
# ..        ...    ...      ...  ..  ..                ...
# 644         1      5        4  10  11  average_achieving
# 645         1      1        4  15  15     well_achieving
# 646         0      5        6  11  12  average_achieving
# 647         1      2        6  10  10  average_achieving
# 648         1      5        4  10  11  average_achieving
#
# [1044 rows x 16 columns]

# %% [markdown]
# ### applying Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
x1=student_data1.drop(['G3'],axis=1)
y1=student_data1['G3']

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.2)

# %%
model1=RandomForestClassifier(n_estimators=20)

# %%
model1.fit(x1_train,y1_train)
# Out:
# RandomForestClassifier(n_estimators=20)

# %%
y1_predict=model1.predict(x1_test)
y1_predict
# Out:
# array(['poor_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'well_achieving', 'average_achieving',
#        'average_achieving', 'well_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'poor_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'poor_achieving', 'average_achieving',
#        'average_achieving', 'well_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'well_achieving',
#        'average_achieving', 'average_achieving', 'well_achieving',
#        'average_achieving', 'poor_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'well_achieving', 'poor_achieving', 'average_achieving',
#        'well_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'poor_achieving',
#        'average_achieving', 'well_achieving', 'well_achieving',
#        'average_achieving', 'average_achieving', 'poor_achieving',
#        'average_achieving', 'well_achieving', 'average_achieving',
#        'poor_achieving', 'average_achieving', 'poor_achieving',
#        'well_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'well_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'well_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'well_achieving', 'average_achieving',
#        'average_achieving', 'well_achieving', 'average_achieving',
#        'well_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'poor_achieving',
#        'average_achieving', 'well_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'well_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'well_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'well_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'poor_achieving',
#        'average_achieving', 'average_achieving', 'well_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'well_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'well_achieving',
#        'average_achieving', 'well_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'well_achieving',
#        'average_achieving', 'well_achieving', 'average_achieving',
#        'well_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'well_achieving', 'average_achieving', 'well_achieving',
#        'average_achieving', 'well_achieving', 'well_achieving',
#        'average_achieving', 'poor_achieving', 'average_achieving',
#        'well_achieving', 'well_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'well_achieving', 'average_achieving', 'well_achieving',
#        'poor_achieving', 'poor_achieving', 'well_achieving',
#        'average_achieving', 'well_achieving', 'well_achieving',
#        'average_achieving', 'average_achieving', 'well_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'well_achieving', 'poor_achieving', 'well_achieving',
#        'average_achieving', 'average_achieving', 'average_achieving',
#        'average_achieving', 'average_achieving'], dtype=object)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y1_test,y1_predict)
# Out:
# 0.8564593301435407

# %%
from sklearn.metrics import confusion_matrix

# %%
performance=confusion_matrix(y1_test,y1_predict)
performance
# Out:
# array([[129,   4,   2],
#        [  9,  11,   0],
#        [ 15,   0,  39]], dtype=int64)
